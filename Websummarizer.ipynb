# %% [markdown]
# Hello There! My name is kelvin Mwangi! Excited to begin my journey in LLM_Engineering. In this particular Section, I'll be handling building my first_llm product.Can't wait to get started!I'll begin with imports.

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# %% [markdown]
# The next cell is where I  load in the environment variables in my .env file and connect to OpenAI.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# %% [markdown]
# I have to make a test call to the frontier model gpt-4o-mini

# %%
message="Hello Gpt, This is my first ever message to you. How are you doing?"
response = openai.chat.completions.create(model="gpt-4o-mini",messages=[{"role":"user","content": message}])
print(response.choices[0].message.content)
# Out:
# Hello! I'm here and ready to help. How can I assist you today?

# %% [markdown]
# Now that the call connection is well set, Lets move on!

# %%
# A class to represent a Webpage
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}
class Website:
    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """

        self.url=url
        response=requests.get(url, headers=headers)
        soup= BeautifulSoup(response.content , "html.parser")
        self.title=soup.title.string if soup.title else "No tile found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
            
            self.text=soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://www.fawco.org/global-issues/education/education-articles/4949-education-round-up-january")
print(ed.title)
print(ed.text)
# Out:
# An Overview of the Education System in Kenya
# Log in
# Log in
# Remember Me
# Log in
# Forgot your username and/or password?
# Sign up
# Login with FAWCO email
# Find a Club
# Join Us
# Subscribe
# Home
# About
# FAWCO News
# Who We Are
# Board
# Volunteers
# How We Work
# Mission Statement
# Resolutions & Recommendations
# History
# FAWCO Awards
# Support FAWCO
# FAWCO Calendar
# Events
# Conferences
# Past Conferences
# 2024 Porto
# 2023 Bratislava
# 2022 IM Parts 1 & 2
# 2021 Virtual Biennial
# 2020 Luxembourg IM (Cancelled)
# 2019 Edinburgh
# 2018 The Hague IM
# 2017 Mumbai
# 2016 Frankfurt IM
# 2015 Rome
# 2014 Brussels IC
# 2013 Bern
# 2012 Dublin IC
# 2011 Marrakech
# 2010 Boston IC
# 2009 Vilnius
# 2008 Seoul IC
# Upcoming Conference
# Regional Meetings
# Upcoming Regional Meetings
# Past Regional Meetings
# Virtual Events
# Inspiring Women Live 2022
# Environment Festival 2022
# Environment Festival 2021
# Human Rights in Focus Virtual Conference
# Publications
# ...

# %% [markdown]
# Defining my System prompt

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %% [markdown]
# To test the prompt i run the cell below

# %%
system_prompt
# Out:
# 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'

# %% [markdown]
# Ok! I can see that it is functional.

# %%
print(user_prompt_for(ed)[:3000])
# Out:
# You are looking at a website titled An Overview of the Education System in Kenya
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# Log in
# Log in
# Remember Me
# Log in
# Forgot your username and/or password?
# Sign up
# Login with FAWCO email
# Find a Club
# Join Us
# Subscribe
# Home
# About
# FAWCO News
# Who We Are
# Board
# Volunteers
# How We Work
# Mission Statement
# Resolutions & Recommendations
# History
# FAWCO Awards
# Support FAWCO
# FAWCO Calendar
# Events
# Conferences
# Past Conferences
# 2024 Porto
# 2023 Bratislava
# 2022 IM Parts 1 & 2
# 2021 Virtual Biennial
# 2020 Luxembourg IM (Cancelled)
# 2019 Edinburgh
# 2018 The Hague IM
# 2017 Mumbai
# 2016 Frankfurt IM
# 2015 Rome
# 2014 Brussels IC
# 2013 Bern
# 2012 Dublin IC
# 2011 Marrakech
# 2010 Boston IC
# 2009 Vilnius
# 2008 Seoul IC
# Upcoming Conference
# Regional Meetings
# ...

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
print(messages_for(ed)[:3000])
# Out:
# [{'role': 'system', 'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'}, {'role': 'user', 'content': "You are looking at a website titled An Overview of the Education System in Kenya\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nLog in\nLog in\nRemember Me\nLog in\nForgot your username and/or password?\nSign up\nLogin with FAWCO email\nFind a Club\nJoin Us\nSubscribe\nHome\nAbout\nFAWCO News\nWho We Are\nBoard\nVolunteers\nHow We Work\nMission Statement\nResolutions & Recommendations\nHistory\nFAWCO Awards\nSupport FAWCO\nFAWCO Calendar\nEvents\nConferences\nPast Conferences\n2024 Porto\n2023 Bratislava\n2022 IM Parts 1 & 2\n2021 Virtual Biennial\n2020 Luxembourg IM (Cancelled)\n2019 Edinburgh\n2018 The Hague IM\n2017 Mumbai\n2016 Frankfurt
# ...

# %%
model="gpt-4o-mini"

# %%
def summarize(url):
    website=Website(url)
    response= openai.chat.completions.create(
        model=model, messages=messages_for(website)
    )
    
    return response.choices[0].message.content

# %%
summarize("https://www.fawco.org/global-issues/education/education-articles/4949-education-round-up-january")
# Out:
# '## Summary of "An Overview of the Education System in Kenya"\n\nThe article by Hollie Nielsen outlines key aspects of the education system in Kenya, particularly the challenges faced by students in slum areas. \n\n- **Educational Structure**: The system comprises three levels: eight years of compulsory primary education, four years of secondary education, and four years of higher education. The government provides free primary and secondary education. However, completion rates are significantly lower, with only 63% of boys and 68% of girls finishing primary education, and a mere 53% enrolling in secondary school.\n\n- **Issues in Education**: Although Kenya has achieved relatively high literacy rates (over 80%), the quality of education suffers from inadequate facilities, overcrowded classrooms, and a severe shortage of qualified teachers. A deficit of over 90,000 teachers persists, and many students attend classes in unsuitable conditions, like makeshift classrooms or under trees.\
# ...

# %% [markdown]
# For clear and neat output, I have added a code below

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

summarize("https://www.fawco.org/global-issues/education/education-articles/4949-education-round-up-january")
# Out:
# '# Summary of "An Overview of the Education System in Kenya"\n\nThe article, authored by Hollie Nielsen, explores the educational landscape in Kenya with a specific focus on gender disparities and the challenges faced by students, particularly in slum areas. It outlines the structure of Kenya\'s education system, which consists of:\n\n- **Primary Education:** Eight years, compulsory starting at age six with free schooling provided by the government.\n- **Secondary Education:** Four years, accessible upon passing the Kenyan Certificate of Primary Education.\n- **Higher Education:** Four years, following secondary school.\n\nKey findings include:\n\n- Although the literacy rate exceeds 80%, there are significant challenges in primary and secondary school completion, especially for girls. Factors hindering these completions include teenage pregnancies, early marriages, poverty, and lack of mentorship.\n- Only 63% of boys and 68% of girls complete primary education, with mere 53% enrolli
# ...
